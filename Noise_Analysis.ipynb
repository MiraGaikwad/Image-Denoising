# %%
import os
import skimage.io
import cv2
from matplotlib import pyplot as plt
from matplotlib import rcParams

# Adjust figure sizes
plt.rcParams['figure.figsize'] = [14, 10]
plt.rcParams['figure.dpi'] = 100 

noisy_im_dir = 'Task-A-Dataset-denoising\\noisy10'
org_im_dir = 'Task-A-Dataset-denoising\\original'

fig, ax = plt.subplots(5,5)

for e, i in enumerate(os.listdir(noisy_im_dir)):

    img_name = i.split(".")[0]+".png"

#     noisy_img = cv2.imread(os.path.join(noisy_im_dir, img_name))           # Noisy10 Images
    org_img = cv2.imread(os.path.join(org_im_dir, img_name))               # Original Images

    noise = org_img

    if e < 5:
        n, bins, patches =  ax[0,e].hist(noise.ravel(), bins = 256)      
        ax[0,e].set_title(img_name)
        ax[0,e].axis('off')
    elif e>=5 and e<10:
        n, bins, patches = ax[1,e-5].hist(noise.ravel(), bins = 256)
        ax[1,e-5].set_title(img_name)
        ax[1,e-5].axis('off')
    elif e>=10 and e<15:
        n, bins, patches =  ax[2,e-10].hist(noise.ravel(), bins = 256)
        ax[2,e-10].set_title(img_name)
        ax[2,e-10].axis('off')
    elif e>=15 and e<20:
        n, bins, patches =  ax[3,e-15].hist(noise.ravel(), bins = 256)
        ax[3,e-15].set_title(img_name)
        ax[3,e-15].axis('off')
    else:
        n, bins, patches =  ax[4,e-20].hist(noise.ravel(), bins = 256)
        ax[4,e-20].set_title(img_name)
        ax[4,e-20].axis('off')

plt.show()

# %% [markdown]
# # Noise level in Noisy10 Image

# %%
import os
import skimage.io
import cv2
from matplotlib import pyplot as plt
from matplotlib import rcParams

# Adjust figure sizes
plt.rcParams['figure.figsize'] = [14, 10]
plt.rcParams['figure.dpi'] = 100 

noisy_im_dir = 'Task-A-Dataset-denoising\\noisy10'
org_im_dir = 'Task-A-Dataset-denoising\\original'

fig, ax = plt.subplots(5,5)

for e, i in enumerate(os.listdir(noisy_im_dir)):

    img_name = i.split(".")[0]+".png"

    noisy_img = cv2.imread(os.path.join(noisy_im_dir, img_name))           # Noisy10 Images
    org_img = cv2.imread(os.path.join(org_im_dir, img_name))               # Original Images

    noise = org_img - noisy_img

    if e < 5:
        n, bins, patches =  ax[0,e].hist(noise.ravel(), bins = 256)      
        ax[0,e].set_title(img_name)
        ax[0,e].axis('off')
    elif e>=5 and e<10:
        n, bins, patches = ax[1,e-5].hist(noise.ravel(), bins = 256)
        ax[1,e-5].set_title(img_name)
        ax[1,e-5].axis('off')
    elif e>=10 and e<15:
        n, bins, patches =  ax[2,e-10].hist(noise.ravel(), bins = 256)
        ax[2,e-10].set_title(img_name)
        ax[2,e-10].axis('off')
    elif e>=15 and e<20:
        n, bins, patches =  ax[3,e-15].hist(noise.ravel(), bins = 256)
        ax[3,e-15].set_title(img_name)
        ax[3,e-15].axis('off')
    else:
        n, bins, patches =  ax[4,e-20].hist(noise.ravel(), bins = 256)
        ax[4,e-20].set_title(img_name)
        ax[4,e-20].axis('off')

plt.show()

# %% [markdown]
# # Noise level in Noisy25 Image

# %%
import os
import skimage.io
import cv2
from matplotlib import pyplot as plt
from matplotlib import rcParams

# Adjust figure sizes
plt.rcParams['figure.figsize'] = [14, 10]
plt.rcParams['figure.dpi'] = 100 

noisy_im_dir = 'Task-A-Dataset-denoising\\noisy25'
org_im_dir = 'Task-A-Dataset-denoising\\original'

fig, ax = plt.subplots(5,5)

for e, i in enumerate(os.listdir(noisy_im_dir)):

    img_name = i.split(".")[0]+".png"

    noisy_img = cv2.imread(os.path.join(noisy_im_dir, img_name))           # Noisy25 Images
    org_img = cv2.imread(os.path.join(org_im_dir, img_name))               # Original Images

    noise = org_img - noisy_img

    if e < 5:
        n, bins, patches =  ax[0,e].hist(noise.ravel(), bins = 256)      
        ax[0,e].set_title(img_name)
        ax[0,e].axis('off')
    elif e>=5 and e<10:
        n, bins, patches = ax[1,e-5].hist(noise.ravel(), bins = 256)
        ax[1,e-5].set_title(img_name)
        ax[1,e-5].axis('off')
    elif e>=10 and e<15:
        n, bins, patches =  ax[2,e-10].hist(noise.ravel(), bins = 256)
        ax[2,e-10].set_title(img_name)
        ax[2,e-10].axis('off')
    elif e>=15 and e<20:
        n, bins, patches =  ax[3,e-15].hist(noise.ravel(), bins = 256)
        ax[3,e-15].set_title(img_name)
        ax[3,e-15].axis('off')
    else:
        n, bins, patches =  ax[4,e-20].hist(noise.ravel(), bins = 256)
        ax[4,e-20].set_title(img_name)
        ax[4,e-20].axis('off')

plt.show()

# %% [markdown]
# # Noise level in Noisy50 Image

# %%
import os
import skimage.io
import cv2
from matplotlib import pyplot as plt
from matplotlib import rcParams

# Adjust figure sizes
plt.rcParams['figure.figsize'] = [14, 10]
plt.rcParams['figure.dpi'] = 100 

noisy_im_dir = 'Task-A-Dataset-denoising\\noisy50'
org_im_dir = 'Task-A-Dataset-denoising\\original'

fig, ax = plt.subplots(5,5)

for e, i in enumerate(os.listdir(noisy_im_dir)):

    img_name = i.split(".")[0]+".png"

    noisy_img = cv2.imread(os.path.join(noisy_im_dir, img_name))           # Noisy25 Images
    org_img = cv2.imread(os.path.join(org_im_dir, img_name))               # Original Images

    noise = org_img - noisy_img

    if e < 5:
        n, bins, patches =  ax[0,e].hist(noise.ravel(), bins = 256)      
        ax[0,e].set_title(img_name)
        ax[0,e].axis('off')
    elif e>=5 and e<10:
        n, bins, patches = ax[1,e-5].hist(noise.ravel(), bins = 256)
        ax[1,e-5].set_title(img_name)
        ax[1,e-5].axis('off')
    elif e>=10 and e<15:
        n, bins, patches =  ax[2,e-10].hist(noise.ravel(), bins = 256)
        ax[2,e-10].set_title(img_name)
        ax[2,e-10].axis('off')
    elif e>=15 and e<20:
        n, bins, patches =  ax[3,e-15].hist(noise.ravel(), bins = 256)
        ax[3,e-15].set_title(img_name)
        ax[3,e-15].axis('off')
    else:
        n, bins, patches =  ax[4,e-20].hist(noise.ravel(), bins = 256)
        ax[4,e-20].set_title(img_name)
        ax[4,e-20].axis('off')

plt.show()
